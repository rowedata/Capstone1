# %% [markdown]
# # Modeling

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot # What does this do? Find out and type here.
from sklearn.metrics import mean_squared_error, r2_score # What does this do? Find out and type here.
from sklearn.model_selection import train_test_split #  What does this do? Find out and type here.
from sklearn import linear_model, preprocessing
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression


from sklearn import tree, metrics
from io import StringIO  
from IPython.display import Image  
import pydotplus
from sklearn.decomposition import PCA

# %%
X = pd.read_csv('data/data_for_modeling.csv')

# %%
X.columns
# Out:
# Index(['Eff Yr Built', 'Above Grd SF', 'Basemt Tot SF', 'Basemt Fin SF',
#        'Garage SF', 'Est Land SF', 'Unincorporated', 'Design_1 Sty Townh',
#        'Design_Bi Level', 'Design_Modular', 'Design_Multi Sty',
#        'Design_Paired', 'Design_Ranch', 'Design_Split level', 'Quality_cat',
#        'Garage Attached', 'Market Area_101', 'Market Area_102',
#        'Market Area_103', 'Market Area_104', 'Market Area_105',
#        'Market Area_106', 'Market Area_107', 'Market Area_401',
#        'Market Area_402', 'Market Area_403', 'Market Area_404',
#        'Market Area_405', 'Time Adjust Sales Price'],
#       dtype='object')

# %% [markdown]
# ## Linear regression model
# 1. Do we need to standardize the variables? No. In general, you do not need to center or standardize your data for multiple regression. Different explanatory variables are almost always on different scales (i.e., measured in different units). This is not a problem; the betas are estimated such that they convert the units of each explanatory variable into the units of the response variable appropriately.

# %%
Y = X['Time Adjust Sales Price']
Y.shape
# Out:
# (10707,)

# %%
features = X.loc[:,['Eff Yr Built', 'Above Grd SF', 'Basemt Tot SF', 'Basemt Fin SF',
       'Garage SF', 'Est Land SF', 'Unincorporated', 'Design_1 Sty Townh',
       'Design_Bi Level', 'Design_Modular', 'Design_Multi Sty',
       'Design_Paired', 'Design_Ranch', 'Design_Split level', 'Quality_cat',
       'Garage Attached', 'Market Area_101', 'Market Area_102',
       'Market Area_103', 'Market Area_104', 'Market Area_105',
       'Market Area_106', 'Market Area_107', 'Market Area_401',
       'Market Area_402', 'Market Area_403', 'Market Area_404',
       'Market Area_405']]

# %%
features.head()
X_train_const = sm.add_constant(features)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_const, Y, test_size = 0.25, train_size = 0.75)

# %%
print(X_train.shape)
print(X_test.columns)
# Out:
# (8030, 29)
# Index(['const', 'Eff Yr Built', 'Above Grd SF', 'Basemt Tot SF',
#        'Basemt Fin SF', 'Garage SF', 'Est Land SF', 'Unincorporated',
#        'Design_1 Sty Townh', 'Design_Bi Level', 'Design_Modular',
#        'Design_Multi Sty', 'Design_Paired', 'Design_Ranch',
#        'Design_Split level', 'Quality_cat', 'Garage Attached',
#        'Market Area_101', 'Market Area_102', 'Market Area_103',
#        'Market Area_104', 'Market Area_105', 'Market Area_106',
#        'Market Area_107', 'Market Area_401', 'Market Area_402',
#        'Market Area_403', 'Market Area_404', 'Market Area_405'],
#       dtype='object')

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()

# %%
results

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Time Adjust Sales Price   R-squared:                       0.741
# Model:                                 OLS   Adj. R-squared:                  0.740
# Method:                      Least Squares   F-statistic:                     847.4
# Date:                     Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                             11:39:39   Log-Likelihood:            -1.1231e+05
# No. Observations:                     8030   AIC:                         2.247e+05
# Df Residuals:                         8002   BIC:                         2.249e+05
# Df Model:                               27
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -3.127e+06   6.05e+05     -5.164      0.000   -4.31e+06   -1.94e+06
# Eff Yr Built        2217.0068    313.458      7.073      0.000    1602.548    2831.466
# Above Grd SF         178.8596      7.490     23.879      0.000     164.177     193.543
# Basemt Tot SF        -55.2156      8.322     -6.635      0.000     -71.528     -38.903
# Basemt Fin SF        122.3210      7.481     16.351      0.000     107.656     136.986
# Garage SF             64.8080     21.452      3.021      0.003      22.757     106.859
# Est Land SF            8.6804      0.444     19.538      0.000       7.809       9.551
# Unincorporated      4.701e+04   2.49e+04      1.884      0.060   -1893.319    9.59e+04
# Design_1 Sty Townh -7.201e+05   2.28e+05     -3.154      0.002   -1.17e+06   -2.73e+05
# Design_Bi Level    -6.484e+05   2.04e+05     -3.171      0.002   -1.05e+06   -2.48e+05
# Design_Modular     -8.455e+05   2.49e+05     -3.392      0.001   -1.33e+06   -3.57e+05
# Design_Multi Sty   -7.954e+05   2.04e+05     -3.904      0.000   -1.19e+06   -3.96e+05
# Design_Paired      -7.934e+05   2.06e+05     -3.859      0.000    -1.2e+06    -3.9e+05
# Design_Ranch        -7.37e+05   2.04e+05     -3.618      0.000   -1.14e+06   -3.38e+05
# Design_Split level -6.989e+05   2.04e+05     -3.427      0.001    -1.1e+06   -2.99e+05
# Quality_cat           8.4e+04   2481.292     33.854      0.000    7.91e+04    8.89e+04
# Garage Attached      -7.4e+04   1.07e+04     -6.892      0.000   -9.51e+04    -5.3e+04
# Market Area_101     3.796e+05   5.04e+04      7.532      0.000    2.81e+05    4.78e+05
# Market Area_102    -1.406e+05    5.2e+04     -2.704      0.007   -2.42e+05   -3.87e+04
# Market Area_103     1.612e+05   5.19e+04      3.107      0.002    5.95e+04    2.63e+05
# Market Area_104    -2.235e+05   5.28e+04     -4.231      0.000   -3.27e+05    -1.2e+05
# Market Area_105    -3.305e+05   5.13e+04     -6.443      0.000   -4.31e+05    -2.3e+05
# Market Area_106     3647.1069   5.12e+04      0.071      0.943   -9.66e+04    1.04e+05
# Market Area_107     1.138e+05   5.24e+04      2.172      0.030    1.11e+04    2.16e+05
# Market Area_401    -5.851e+05   5.43e+04    -10.766      0.000   -6.92e+05   -4.79e+05
# Market Area_402    -6.603e+05   5.29e+04    -12.488      0.000   -7.64e+05   -5.57e+05
# Market Area_403    -4.568e+05   5.18e+04     -8.823      0.000   -5.58e+05   -3.55e+05
# Market Area_404    -7.547e+05   5.56e+04    -13.569      0.000   -8.64e+05   -6.46e+05
# Market Area_405    -6.335e+05   5.26e+04    -12.050      0.000   -7.37e+05    -5.3e+05
# ==============================================================================
# Omnibus:                     7913.795   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1255061.473
# Skew:                           4.401   Prob(JB):                         0.00
# Kurtosis:                      63.611   Cond. No.                     2.45e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.91e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# T-stats look good for all coefficients except unincorporated. https://bouldercounty.gov/government/about-boulder-county/unincorporated-towns/
#
# The Durbin-Watson is right around 2 and between 1.5 and 2.5, so autocorrelation is likely not a cause for concern.
# R squared is better than with scaled variables so definitely don't need it.

# %%
residuals = np.asarray(y_test - results.predict(X_test))

# %%
plt.plot(residuals, 'bo')
plt.show()

# %% [markdown]
# Now let's look at the residual's qqplot.

# %%
reshaped
# Out:
# array([[-88562.56339305],
#        [310184.88695586],
#        [184329.61575295],
#        ...,
#        [ 31515.42753152],
#        [ 69090.56242579],
#        [ 85783.78437784]])

# %%
residuals.shape
# Out:
# (2677,)

# %%
reshaped =np.reshape(residuals, (-1, 1))

# %%
scaler = StandardScaler()
scaler.fit(reshaped)
stand_resid =scaler.transform(reshaped)
fig = sm.qqplot(stand_resid, line='45')
plt.show()

# %% [markdown]
# Residuals do not seem to be normally distributed.

# %%
# Plot the predictions
plt.figure()

# Build a scatterplot

x = np.linspace(0,7000000,)
plt.plot(x,x, color = 'r')
plt.ylim((0,7000000))
plt.xlim((0,7000000))
plt.scatter(y_test, results.predict(X_test))

# Label it nicely
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.title('Predicted price vs actual price')
plt.show()

# %% [markdown]
# Clearly, there is a problem. The second half of the dataset where the problems start showing are the expensive properties, which are hard to model using given variables.

# %% [markdown]
# ### Decision tree

# %%
X_test = X_test.iloc[:,1:]

# %%
X_train =X_train.iloc[:,1:]

# %% [markdown]
# ### PCA

# %%
scaling=StandardScaler()
 
# Use fit and transform method
scaling.fit(X_train)
Scaled_data=scaling.transform(X_train)
 
# Set the n_components=3
principal=PCA(n_components=15)
principal.fit(Scaled_data)
x=principal.transform(Scaled_data)
 
# Check the dimensions of data after PCA
print(x.shape)
# Out:
# (8030, 15)

# %%
#Check the values of eigen vectors
# prodeced by principal components
principal.components_[0]
# Out:
# array([ 0.34827219,  0.42364599,  0.31186857,  0.10671053,  0.35687902,
#         0.08888249, -0.01595728,  0.01295855, -0.09648603, -0.01746011,
#         0.32086775, -0.01003184, -0.23030839, -0.12570363,  0.38345118,
#         0.18725576, -0.06467319,  0.03694506,  0.02084428, -0.13507833,
#        -0.082962  , -0.0945129 , -0.0935676 , -0.00214942,  0.09774114,
#        -0.05236135,  0.17287883,  0.01722929])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1])

plt.xlabel('pc1')
plt.ylabel('pc2')
# Out:
# Text(0, 0.5, 'pc2')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,10))
 
# choose projection 3d for creating a 3d graph
axis = fig.add_subplot(111, projection='3d')
 
# x[:,0]is pc1,x[:,1] is pc2 while x[:,2] is pc3
axis.scatter(x[:,0],x[:,1],x[:,2], c=y_train, cmap='plasma')
axis.set_xlabel("PC1", fontsize=10)
axis.set_ylabel("PC2", fontsize=10)
axis.set_zlabel("PC3", fontsize=10)
# Out:
# Text(0.5, 0, 'PC3')

# %%
# check how much variance is explained by each principal component
print(principal.explained_variance_ratio_)
# Out:
# [0.14462719 0.07458178 0.06349474 0.06034389 0.05253759 0.04828634
#  0.04323721 0.04255703 0.04005323 0.03834065 0.03800633 0.03751657
#  0.03620444 0.03602294 0.03490557]

# %% [markdown]
# Well, it looks like first 3 components don't explain much of the variance, certainly not around 80% level. I would not use them in this case and instead use

# %% [markdown]
# #### Model 1: Entropy model - no max_depth

# %%
X_train
# Out:
#       Eff Yr Built  Above Grd SF  Basemt Tot SF  Basemt Fin SF  Garage SF  \
# 5767          1996          1515            724            652        380
# 9639          1992          1560            780            708        520
# 1382          2012          2387           1225           1225        662
# 3623          2010          2392           1214            957        554
# 5996          1972          1104            904            723        384
# ...            ...           ...            ...            ...        ...
# 6770          2018          3679           1920           1742        763
# 4792          2005           858            828            828          0
# 6975          2007          1276            504              0        396
# 3254          2016          1948           1948           1948        523
# 9598          2003          3932           2200           2200        644
#
#       Est Land SF  Unincorporated  Design_1 Sty Townh  Design_Bi Level  \
# 5767         4449               0                   0                0
# 9639        10831               0                   0                0
# 1382         7386               0                   0                0
# 3623         5521               0                   0                0
# 5996         6799               0                   0                0
# ...           ...             ...                 ...              ...
# 6770        16257               0                   0                0
# 4792         7040               0                   0                1
# 6975         7502               0                   0                0
# 3254         6160               0                   0                0
# 9598        12389               0                   0                0
#
#       Design_Modular  ...  Market Area_103  Market Area_104  Market Area_105  \
# 5767               0  ...                0                0                0
# 9639               0  ...                0                0                1
# 1382               0  ...                0                0                0
# 3623               0  ...                0                0                0
# 5996               0  ...                0                0                0
# ...              ...  ...              ...              ...              ...
# 6770               0  ...                0                0                0
# 4792               0  ...                0                0                0
# 6975               0  ...                0                0                0
# 3254               0  ...                0                0                0
# 9598               0  ...                0                0                1
#
#       Market Area_106  Market Area_107  Market Area_401  Market Area_402  \
# 5767                0                0                0                0
# 9639                0                0                0                0
# 1382                0                0                0                1
# 3623                0                0                0                0
# 5996                0                0                0                0
# ...               ...              ...              ...              ...
# 6770                0                0                0                0
# 4792                0                0                0                0
# 6975                0                0                0                0
# 3254                0                0                0                0
# 9598                0                0                0                0
#
#       Market Area_403  Market Area_404  Market Area_405
# 5767                0                0                1
# 9639                0                0                0
# 1382                0                0                0
# 3623                0                1                0
# 5996                0                0                1
# ...               ...              ...              ...
# 6770                0                0                1
# 4792                0                0                1
# 6975                0                0                1
# 3254                0                1                0
# 9598                0                0                0
#
# [8030 rows x 28 columns]

# %%
# Declare a variable called entr_model and use tree.DecisionTreeClassifier. 
entr_model = tree.DecisionTreeRegressor()

# Call fit() on entr_model
entr_model.fit(X_train, y_train)

# Call predict() on entr_model with X_test passed to it, and assign the result to a variable y_pred 
y_pred = entr_model.predict(X_test)

# Call Series on our y_pred variable with the following: pd.Series(y_pred)
y_pred =pd.Series(y_pred)

# Check out entr_model
entr_model
# Out:
# DecisionTreeRegressor()

# %%
tree.plot_tree(entr_model)
# Out:
# [Text(0.8969754139878519, 0.9857142857142858, 'X[14] <= 7.5\nsquared_error = 317661431734.185\nsamples = 8030\nvalue = 893946.755'),
#  Text(0.802822322932522, 0.9571428571428572, 'X[14] <= 5.5\nsquared_error = 123509676748.396\nsamples = 7534\nvalue = 806246.85'),
#  Text(0.690559793902034, 0.9285714285714286, 'X[16] <= 0.5\nsquared_error = 76721786410.942\nsamples = 5996\nvalue = 731533.17'),
#  Text(0.6556329871437317, 0.9, 'X[18] <= 0.5\nsquared_error = 57440546739.791\nsamples = 5730\nvalue = 705983.613'),
#  Text(0.6084095326806946, 0.8714285714285714, 'X[21] <= 0.5\nsquared_error = 48485723053.486\nsamples = 5515\nvalue = 688864.474'),
#  Text(0.5591659418435817, 0.8428571428571429, 'X[22] <= 0.5\nsquared_error = 40975466754.722\nsamples = 5166\nvalue = 667790.02'),
#  Text(0.4971628032358373, 0.8142857142857143, 'X[17] <= 0.5\nsquared_error = 32095670890.028\nsamples = 4904\nvalue = 649217.186'),
#  Text(0.4046503878718855, 0.7857142857142857, 'X[20] <= 0.5\nsquared_error = 21454302950.674\nsamples = 4629\nvalue = 628777.294'),
#  Text(0.26389411012997027, 0.7571428571428571, 'X[1] <= 1614.5\nsquared_error = 17015171336.516\nsamples = 4240\nvalue = 612237.552'),
#  Text(0.12753547495237147, 0.7285714285714285, 'X[27] <= 0.5\nsquared_error = 13327561088.781\nsamples = 1673\nvalue = 547410.566'),
#  Text(0.09638662678787764, 0.7, 'X[26] <= 0.5\nsquared_error = 12707006942.053\nsamples = 1001\nvalue = 594687.538'),
#  Text(0.074377032835338, 0.6714285714285714, 'X[19] <= 0.5\nsquared_error = 9211805718.752\nsamples = 844\nvalue = 624169.938'),
#  Text(0.05435646835502331, 0.6428571428571429, 'X[14] <= 3.5\nsquared_error = 7322695904.64\nsamples = 643\nvalue = 600737.335'),
#  Text(0.032427299140446765, 0.6142857142857143, 'X[14] <= 1.5\nsquared_error = 5396717848.31\nsamples = 535\nvalue = 584564.402'),
#  Text(0.018747518747454756, 0.5857142857142857, 'X[4] <= 804.5\nsquared_error = 6466328794.943\nsamples = 224\nvalue = 560218.204'),
#  Text(0.011633442945717425, 0.5571428571428572, 'X[5] <= 5891.5\nsquared_error = 5589049985.475\nsamples = 219\nvalue = 555610.9'),
#  Text(0.004230575584039816, 0.5285714285714286, 'X[2] <= 175.0\nsquared_error = 3371571265.68\nsamples = 65\nvalue = 519305.909'),
#  Text(0.0013596816010660396, 0.5, 'X[0] <= 1988.0\nsquared_error = 4194040350.494\nsamples = 13\nvalue = 464899.831'),
#  Text(0.0008846121259947727, 0.4714285714285714, 'X[4] <= 320.0\nsquared_error = 2208834752.213\nsamples = 10\nvalue = 441042.529'),
#  Text(0.0005242145931820875, 0.44285714285714284, 'X[5] <= 5097.5\nsquared_error = 872500650.533\nsamples = 4\nvalue = 402508.392'),
#  Text(0.0003931609448865656, 0.4142857142857143, 'X[23] <= 0.5\nsquared_error = 190852238.274\nsamples = 3\nvalue = 418100.714'),
#  Text(0.00026210729659104375, 0.38571428571428573, 'X[1] <= 692.0\nsquared_error = 0.0\nsamples = 2\nvalue = 408332.084'),
#  Text(0.00013105364829552187, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 408332.084'),
#  Text(0.0003931609448865656, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 408332.084'),
#  Text(0.0005242145931820875, 0.38571428571428573, 'squared_error = -0.0\nsamples = 1\nvalue = 437637.972'),
#  Text(0.0006552682414776094, 0.4142857142857143, 'squared_error = -0.0\nsamples = 1\nvalue = 355731.428'),
#  Text(0.0012450096588074579, 0.44285714285714284, 'X[4] <= 393.5\nsquared_error = 1449857809.037\nsamples = 6\nvalue = 466731.954'),
#  Text(0.0009173755380686532, 0.4142857142857143, 'X[5] <= 3523.5\nsquared_error = 89462662.005\nsamples = 2\nvalue = 508668.692'),
#  Text(0.0007863218897731312, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 499210.222'),
#  Text(0.001048429186364175, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 518127.162'),
#  Text(0.0015726437795462625, 0.4142857142857143, 'X[5] <= 4952.5\nsquared_error = 811037861.66\nsamples = 4\nvalue = 445763.585'),
#  Text(0.0013105364829552187, 0.38571428571428573, 'X[5] <= 4827.0\nsquared_error = 417492857.153\nsamples = 2\nvalue = 458001.193'),
#  Text(0.001179482834659697, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 437568.551'),
#  Text(0.0014415901312507407, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 478433.835'),
#  Text(0.0018347510761373064, 0.38571428571428573, 'X[25] <= 0.5\nsquared_error = 905064736.48\nsamples = 2\nvalue = 433525.976'),
#  Text(0.0017036974278417845, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 463610.27'),
#  Text(0.001965804724432828, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 403441.682'),
#  Text(0.0018347510761373064, 0.4714285714285714, 'X[25] <= 0.5\nsquared_error = 2590035589.585\nsamples = 3\nvalue = 544424.17'),
#  Text(0.0017036974278417845, 0.44285714285714284, 'squared_error = 0.0\nsamples = 1\nvalue = 479711.995'),
#  Text(0.001965804724432828, 0.44285714285714284, 'X[10] <= 0.5\nsquared_error = 744304185.731\nsamples = 2\nvalue = 576780.258'),
#  Text(0.0018347510761373064, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 604062.197'),
#  Text(0.00209685837272835, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 549498.319'),
#  Text(0.007101469567013592, 0.5, 'X[24] <= 0.5\nsquared_error = 2240947324.701\nsamples = 52\nvalue = 532907.429'),
#  Text(0.005291291049931696, 0.4714285714285714, 'X[0] <= 1985.5\nsquared_error = 1776668705.871\nsamples = 44\nvalue = 541527.711'),
#  Text(0.00347292167983133, 0.44285714285714284, 'X[3] <= 862.0\nsquared_error = 1537558079.333\nsamples = 17\nvalue = 512471.821'),
#  Text(0.003014233910797003, 0.4142857142857143, 'X[5] <= 5350.0\nsquared_error = 1038418699.437\nsamples = 15\nvalue = 503667.211'),
#  Text(0.0024900193176149157, 0.38571428571428573, 'X[5] <= 4993.0\nsquared_error = 1091253579.688\nsamples = 9\nvalue = 490755.178'),
#  Text(0.002227912021023872, 0.35714285714285715, 'X[23] <= 0.5\nsquared_error = 590746809.053\nsamples = 7\nvalue = 504173.762'),
#  Text(0.00209685837272835, 0.32857142857142857, 'X[0] <= 1970.5\nsquared_error = 375751614.692\nsamples = 6\nvalue = 510865.473'),
#  Text(0.001965804724432828, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 539535.009'),
#  Text(0.002227912021023872, 0.3, 'X[3] <= 191.0\nsquared_error = 253635791.108\nsamples = 5\nvalue = 505131.566'),
#  Text(0.00209685837272835, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 476334.199'),
#  Text(0.002358965669319394, 0.2714285714285714, 'X[5] <= 4407.0\nsquared_error = 57892119.026\nsamples = 4\nvalue = 512330.908'),
#  Text(0.00209685837272835, 0.24285714285714285, 'X[2] <= 660.0\nsquared_error = 16223734.534\nsamples = 2\nvalue = 519260.184'),
#  Text(0.001965804724432828, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 515232.314'),
#  Text(0.002227912021023872, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 523288.054'),
#  Text(0.0026210729659104375, 0.24285714285714285, 'X[8] <= 0.5\nsquared_error = 3530779.822\nsamples = 2\nvalue = 505401.632'),
#  Text(0.0024900193176149157, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 503522.596'),
#  Text(0.0027521266142059597, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 507280.669'),
#  Text(0.002358965669319394, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 464023.495'),
#  Text(0.0027521266142059597, 0.35714285714285715, 'X[1] <= 976.0\nsquared_error = 7107268.724\nsamples = 2\nvalue = 443790.131'),
#  Text(0.0026210729659104375, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 441124.185'),
#  Text(0.0028831802625014814, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 446456.077'),
#  Text(0.0035384485039790907, 0.38571428571428573, 'X[0] <= 1982.5\nsquared_error = 333964120.239\nsamples = 6\nvalue = 523035.261'),
#  Text(0.003276341207388047, 0.35714285714285715, 'X[1] <= 1230.0\nsquared_error = 241395438.542\nsamples = 4\nvalue = 513796.935'),
#  Text(0.003145287559092525, 0.32857142857142857, 'X[5] <= 5552.5\nsquared_error = 55823125.504\nsamples = 3\nvalue = 505641.607'),
#  Text(0.003014233910797003, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 515856.118'),
#  Text(0.003276341207388047, 0.3, 'X[13] <= 0.5\nsquared_error = 5482524.452\nsamples = 2\nvalue = 500534.352'),
#  Text(0.003145287559092525, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 502875.831'),
#  Text(0.003407394855683569, 0.2714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 498192.873'),
#  Text(0.003407394855683569, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 538262.917'),
#  Text(0.0038005558005701347, 0.35714285714285715, 'X[0] <= 1984.0\nsquared_error = 7021490.957\nsamples = 2\nvalue = 541511.912'),
#  Text(0.003669502152274613, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 538862.103'),
#  Text(0.003931609448865656, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 544161.722'),
#  Text(0.003931609448865656, 0.4142857142857143, 'X[2] <= 912.0\nsquared_error = 339129924.75\nsamples = 2\nvalue = 578506.394'),
#  Text(0.0038005558005701347, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 596921.874'),
#  Text(0.004062663097161179, 0.38571428571428573, 'squared_error = -0.0\nsamples = 1\nvalue = 560090.913'),
#  Text(0.007109660420032062, 0.44285714285714284, 'X[1] <= 1167.0\nsquared_error = 1060971464.069\nsamples = 27\nvalue = 559822.16'),
#  Text(0.006028467821594006, 0.4142857142857143, 'X[3] <= 664.0\nsquared_error = 471957627.513\nsamples = 17\nvalue = 544678.997'),
#  Text(0.005242145931820875, 0.38571428571428573, 'X[2] <= 482.0\nsquared_error = 385302634.862\nsamples = 11\nvalue = 552348.354'),
#  Text(0.004717931338638788, 0.35714285714285715, 'X[5] <= 4953.5\nsquared_error = 332143164.497\nsamples = 8\nvalue = 545597.466'),
#  Text(0.0041937167454567, 0.32857142857142857, 'X[4] <= 369.5\nsquared_error = 151891480.644\nsamples = 4\nvalue = 557980.231'),
#  Text(0.003931609448865656, 0.3, 'X[0] <= 1994.0\nsquared_error = 10205709.652\nsamples = 2\nvalue = 546520.144'),
#  Text(0.0038005558005701347, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 549714.782'),
#  Text(0.004062663097161179, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 543325.507'),
#  Text(0.004455824042047744, 0.3, 'X[0] <= 2001.0\nsquared_error = 30910059.409\nsamples = 2\nvalue = 569440.318'),
#  Text(0.004324770393752222, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 563880.637'),
#  Text(0.004586877690343266, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 575000.0'),
#  Text(0.005242145931820875, 0.32857142857142857, 'X[0] <= 1988.5\nsquared_error = 205729088.753\nsamples = 4\nvalue = 533214.7'),
#  Text(0.004980038635229831, 0.3, 'X[0] <= 1987.0\nsquared_error = 257621060.193\nsamples = 2\nvalue = 541964.847'),
#  Text(0.004848984986934309, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 525914.268'),
#  Text(0.005111092283525354, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 558015.425'),
#  Text(0.005504253228411919, 0.3, 'X[1] <= 1004.0\nsquared_error = 707002.464\nsamples = 2\nvalue = 524464.554'),
#  Text(0.005373199580116397, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 523623.72'),
#  Text(0.005635306876707441, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 525305.389'),
#  Text(0.005766360525002963, 0.35714285714285715, 'X[5] <= 4248.0\nsquared_error = 81443942.088\nsamples = 3\nvalue = 570350.723'),
#  Text(0.005635306876707441, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 558775.078'),
#  Text(0.005897414173298485, 0.32857142857142857, 'X[2] <= 494.0\nsquared_error = 21669232.603\nsamples = 2\nvalue = 576138.546'),
#  Text(0.005766360525002963, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 580793.569'),
#  Text(0.006028467821594006, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 571483.524'),
#  Text(0.006814789711367138, 0.38571428571428573, 'X[1] <= 916.0\nsquared_error = 325292893.982\nsamples = 6\nvalue = 530618.509'),
#  Text(0.006683736063071616, 0.35714285714285715, 'X[3] <= 804.0\nsquared_error = 230638456.068\nsamples = 5\nvalue = 535777.854'),
#  Text(0.006421628766480572, 0.32857142857142857, 'X[0] <= 1986.5\nsquared_error = 53157827.189\nsamples = 3\nvalue = 547137.658'),
#  Text(0.00629057511818505, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 538000.0'),
#  Text(0.006552682414776094, 0.3, 'X[1] <= 860.0\nsquared_error = 17114147.905\nsamples = 2\nvalue = 551706.487'),
#  Text(0.006421628766480572, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 555843.412'),
#  Text(0.006683736063071616, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 547569.562'),
#  Text(0.00694584335966266, 0.32857142857142857, 'X[5] <= 4821.0\nsquared_error = 12940111.895\nsamples = 2\nvalue = 518738.148'),
#  Text(0.006814789711367138, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 515140.912'),
#  Text(0.007076897007958181, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 522335.385'),
#  Text(0.00694584335966266, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 504821.787'),
#  Text(0.008190853018470117, 0.4142857142857143, 'X[1] <= 1481.0\nsquared_error = 1009737443.869\nsamples = 10\nvalue = 585565.536'),
#  Text(0.008059799370174595, 0.38571428571428573, 'X[23] <= 0.5\nsquared_error = 569809446.596\nsamples = 9\nvalue = 578135.051'),
#  Text(0.007797692073583552, 0.35714285714285715, 'X[1] <= 1428.0\nsquared_error = 344862947.757\nsamples = 7\nvalue = 569272.271'),
#  Text(0.00766663842528803, 0.32857142857142857, 'X[3] <= 504.0\nsquared_error = 242094855.767\nsamples = 6\nvalue = 574056.848'),
#  Text(0.007339004304549226, 0.3, 'X[1] <= 1306.5\nsquared_error = 188121060.448\nsamples = 4\nvalue = 581520.854'),
#  Text(0.007076897007958181, 0.2714285714285714, 'X[12] <= 0.5\nsquared_error = 1715388.867\nsamples = 2\nvalue = 593361.328'),
#  Text(0.00694584335966266, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 594671.057'),
#  Text(0.007207950656253704, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 592051.599'),
#  Text(0.007601111601140269, 0.2714285714285714, 'X[2] <= 413.0\nsquared_error = 94133103.807\nsamples = 2\nvalue = 569680.381'),
#  Text(0.007470057952844747, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 579382.602'),
#  Text(0.007732165249435791, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 559978.159'),
#  Text(0.007994272546026835, 0.3, 'X[4] <= 420.0\nsquared_error = 15774096.718\nsamples = 2\nvalue = 559128.835'),
#  Text(0.007863218897731313, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 563100.497'),
#  Text(0.008125326194322357, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 555157.173'),
#  Text(0.007928745721879073, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 540564.808'),
#  Text(0.00832190666676564, 0.35714285714285715, 'X[3] <= 570.0\nsquared_error = 119977441.865\nsamples = 2\nvalue = 609154.782'),
#  Text(0.008190853018470117, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 620108.203'),
#  Text(0.008452960315061162, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 598201.36'),
#  Text(0.00832190666676564, 0.38571428571428573, 'squared_error = -0.001\nsamples = 1\nvalue = 652439.899'),
#  Text(0.008911648084095489, 0.4714285714285714, 'X[5] <= 3270.5\nsquared_error = 2137923728.141\nsamples = 8\nvalue = 485495.879'),
#  Text(0.008584013963356684, 0.44285714285714284, 'X[5] <= 3111.5\nsquared_error = 340716949.365\nsamples = 2\nvalue = 555268.106'),
#  Text(0.008452960315061162, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 536809.587'),
#  Text(0.008715067611652205, 0.4142857142857143, 'squared_error = -0.0\nsamples = 1\nvalue = 573726.626'),
#  Text(0.009239282204834293, 0.44285714285714284, 'X[1] <= 1309.0\nsquared_error = 573364308.915\nsamples = 6\nvalue = 462238.469'),
#  Text(0.008977174908243249, 0.4142857142857143, 'X[5] <= 3759.5\nsquared_error = 370073666.18\nsamples = 2\nvalue = 436237.299'),
#  Text(0.008846121259947727, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 417000.0'),
#  Text(0.009108228556538771, 0.38571428571428573, 'squared_error = -0.0\nsamples = 1\nvalue = 455474.598'),
#  Text(0.009501389501425336, 0.4142857142857143, 'X[2] <= 621.5\nsquared_error = 167963978.572\nsamples = 4\nvalue = 475239.055'),
#  Text(0.009370335853129814, 0.38571428571428573, 'X[1] <= 1462.0\nsquared_error = 44483722.413\nsamples = 3\nvalue = 468540.767'),
#  Text(0.009239282204834293, 0.35714285714285715, 'X[2] <= 490.0\nsquared_error = 4437509.176\nsamples = 2\nvalue = 473097.376'),
#  Text(0.009108228556538771, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 475203.916'),
#  Text(0.009370335853129814, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 470990.837'),
#  Text(0.009501389501425336, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 459427.547'),
#  Text(0.009632443149720858, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 495333.919'),
#  Text(0.019036310307395034, 0.5285714285714286, 'X[1] <= 1135.0\nsquared_error = 5733867277.95\nsamples = 154\nvalue = 570934.435'),
#  Text(0.012866294307075591, 0.5, 'X[2] <= 126.0\nsquared_error = 4737184929.198\nsamples = 92\nvalue = 549588.787'),
#  Text(0.010959361338713017, 0.4714285714285714, 'X[4] <= 300.0\nsquared_error = 4761876872.731\nsamples = 16\nvalue = 495254.934'),
#  Text(0.010287711391198467, 0.44285714285714284, 'X[5] <= 7501.5\nsquared_error = 4535589740.287\nsamples = 4\nvalue = 562591.387'),
#  Text(0.010025604094607425, 0.4142857142857143, 'X[15] <= 0.5\nsquared_error = 141901496.904\nsamples = 2\nvalue = 502404.282'),
#  Text(0.009894550446311903, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 514316.523'),
#  Text(0.010156657742902945, 0.38571428571428573, 'squared_error = -0.0\nsamples = 1\nvalue = 490492.04'),
#  Text(0.010549818687789512, 0.4142857142857143, 'X[4] <= 254.0\nsquared_error = 1684302829.151\nsamples = 2\nvalue = 622778.491'),
#  Text(0.01041876503949399, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 663818.75'),
#  Text(0.010680872336085034, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 581738.233'),
#  Text(0.011631011286227568, 0.44285714285714284, 'X[4] <= 616.0\nsquared_error = 2822106883.561\nsamples = 12\nvalue = 472809.45'),
#  Text(0.011499957637932046, 0.4142857142857143, 'X[0] <= 1987.5\nsquared_error = 1577367747.136\nsamples = 11\nvalue = 461624.288'),
#  Text(0.010942979632676077, 0.38571428571428573, 'X[4] <= 324.0\nsquared_error = 702063928.784\nsamples = 8\nvalue = 442509.776'),
#  Text(0.010615345511937272, 0.35714285714285715, 'X[1] <= 958.0\nsquared_error = 59837099.752\nsamples = 2\nvalue = 479753.346'),
#  Text(0.01048429186364175, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 487488.79'),
#  Text(0.010746399160232794, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 472017.902'),
#  Text(0.011270613753414881, 0.35714285714285715, 'X[0] <= 1977.0\nsquared_error = 299657983.582\nsamples = 6\nvalue = 430095.253'),
#  Text(0.011008506456823839, 0.32857142857142857, 'X[0] <= 1959.0\nsquared_error = 247221504.364\nsamples = 2\nvalue = 412969.145'),
#  Text(0.010877452808528316, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 428692.424'),
#  Text(0.01113956010511936, 0.3, 'squared_error = -0.0\nsamples = 1\nvalue = 397245.866'),
#  Text(0.011532721050005926, 0.32857142857142857, 'X[15] <= 0.5\nsquared_error = 105898549.033\nsamples = 4\nvalue = 438658.307'),
#  Text(0.011401667401710404, 0.3, 'squared_error = 202757228.424\nsamples = 2\nvalue = 440730.53'),
#  Text(0.011663774698301448, 0.3, 'X[1] <= 1082.0\nsquared_error = 451646.968\nsamples = 2\nvalue = 436586.083'),
#  Text(0.011532721050005926, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 435914.036'),
#  Text(0.01179482834659697, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 437258.13'),
#  Text(0.012056935643188013, 0.38571428571428573, 'X[0] <= 1992.5\nsquared_error = 339057942.485\nsamples = 3\nvalue = 512596.318'),
#  Text(0.01192588199489249, 0.35714285714285715, 'X[4] <= 356.0\nsquared_error = 373912848.067\nsamples = 2\nvalue = 519296.419'),
#  Text(0.01179482834659697, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 499959.593'),
#  Text(0.012056935643188013, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 538633.245'),
#  Text(0.012187989291483535, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 499196.115'),
#  Text(0.011762064934523088, 0.4142857142857143, 'squared_error = -0.0\nsamples = 1\nvalue = 595846.237'),
#  Text(0.014773227275438165, 0.4714285714285714, 'X[1] <= 864.5\nsquared_error = 3979633680.806\nsamples = 76\nvalue = 561027.492'),
#  Text(0.012908784357108904, 0.44285714285714284, 'X[0] <= 1979.5\nsquared_error = 3835155001.051\nsamples = 15\nvalue = 513671.406'),
#  Text(0.01245009658807458, 0.4142857142857143, 'X[4] <= 457.5\nsquared_error = 1003390214.333\nsamples = 3\nvalue = 430403.649'),
#  Text(0.012319042939779057, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 472031.582'),
#  Text(0.0125811502363701, 0.38571428571428573, 'X[12] <= 0.5\nsquared_error = 205421733.379\nsamples = 2\nvalue = 409589.683'),
#  Text(0.01245009658807458, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 423922.224'),
#  Text(0.012712203884665622, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 395257.142'),
#  Text(0.013367472126143231, 0.4142857142857143, 'X[2] <= 837.5\nsquared_error = 2376371426.401\nsamples = 12\nvalue = 534488.345'),
#  Text(0.013105364829552189, 0.38571428571428573, 'X[2] <= 820.0\nsquared_error = 1777124221.973\nsamples = 10\nvalue = 547369.548'),
#  Text(0.012974311181256666, 0.35714285714285715, 'X[0] <= 1992.5\nsquared_error = 611792033.334\nsamples = 9\nvalue = 535695.687'),
#  Text(0.012712203884665622, 0.32857142857142857, 'X[0] <= 1991.0\nsquared_error = 293089385.521\nsamples = 6\nvalue = 521916.796'),
#  Text(0.0125811502363701, 0.3, 'X[5] <= 8079.0\nsquared_error = 19064075.763\nsamples = 5\nvalue = 529362.636'),
#  Text(0.012319042939779057, 0.2714285714285714, 'X[5] <= 7350.0\nsquared_error = 3543173.245\nsamples = 3\nvalue = 532537.936'),
#  Text(0.012187989291483535, 0.24285714285714285, 'X[1] <= 846.0\nsquared_error = 19337.63\nsamples = 2\nvalue = 531209.35'),
#  Text(0.012056935643188013, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 531348.41'),
#  Text(0.012319042939779057, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 531070.291'),
#  Text(0.01245009658807458, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 535195.108'),
#  Text(0.012843257532961144, 0.2714285714285714, 'X[5] <= 8673.5\nsquared_error = 4535938.206\nsamples = 2\nvalue = 524599.686'),
#  Text(0.012712203884665622, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 526729.46'),
#  Text(0.012974311181256666, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 522469.912'),
#  Text(0.012843257532961144, 0.3, 'squared_error = -0.0\nsamples = 1\nvalue = 484687.597'),
#  Text(0.01323641847784771, 0.32857142857142857, 'X[5] <= 9841.5\nsquared_error = 110050394.023\nsamples = 3\nvalue = 563253.468'),
#  Text(0.013105364829552189, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 551074.285'),
#  Text(0.013367472126143231, 0.3, 'X[5] <= 11773.0\nsquared_error = 53826217.037\nsamples = 2\nvalue = 569343.059'),
#  Text(0.01323641847784771, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 576679.695'),
#  Text(0.013498525774438754, 0.2714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 562006.424'),
#  Text(0.01323641847784771, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 652434.302'),
#  Text(0.013629579422734276, 0.38571428571428573, 'X[5] <= 10445.5\nsquared_error = 394845187.084\nsamples = 2\nvalue = 470082.326'),
#  Text(0.013498525774438754, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 489953.038'),
#  Text(0.013760633071029798, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 450211.614'),
#  Text(0.016637670193767426, 0.44285714285714284, 'X[15] <= 0.5\nsquared_error = 3328097852.168\nsamples = 61\nvalue = 572672.432'),
#  Text(0.014759917139283152, 0.4142857142857143, 'X[5] <= 9510.0\nsquared_error = 5192990693.011\nsamples = 12\nvalue = 610772.022'),
#  Text(0.014383137900433527, 0.38571428571428573, 'X[4] <= 272.0\nsquared_error = 2502019515.016\nsamples = 10\nvalue = 634570.389'),
#  Text(0.01402274036762084, 0.35714285714285715, 'X[1] <= 1032.0\nsquared_error = 50703366.895\nsamples = 2\nvalue = 567786.401'),
#  Text(0.01389168671932532, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 574907.031'),
#  Text(0.014153794015916363, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 560665.772'),
#  Text(0.014743535433246212, 0.35714285714285715, 'X[2] <= 444.0\nsquared_error = 1721066983.29\nsamples = 8\nvalue = 651266.386'),
#  Text(0.014415901312507407, 0.32857142857142857, 'X[4] <= 464.0\nsquared_error = 1118610354.552\nsamples = 2\nvalue = 600416.291'),
#  Text(0.014284847664211885, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 633861.924'),
#  Text(0.01454695496080293, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 566970.658'),
#  Text(0.015071169553985016, 0.32857142857142857, 'X[3] <= 390.0\nsquared_error = 772671572.943\nsamples = 6\nvalue = 668216.418'),
#  Text(0.014809062257393972, 0.3, 'X[5] <= 8518.0\nsquared_error = 404694308.541\nsamples = 4\nvalue = 683963.034'),
#  Text(0.014678008609098452, 0.2714285714285714, 'X[4] <= 537.0\nsquared_error = 125487829.96\nsamples = 3\nvalue = 673788.254'),
#  Text(0.01454695496080293, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 659317.844'),
#  Text(0.014809062257393972, 0.24285714285714285, 'X[0] <= 1979.0\nsquared_error = 31187156.181\nsamples = 2\nvalue = 681023.46'),
#  Text(0.014678008609098452, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 675438.913'),
#  Text(0.014940115905689494, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 686608.006'),
#  Text(0.014940115905689494, 0.2714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 714487.374'),
#  Text(0.01533327685057606, 0.3, 'X[0] <= 1971.5\nsquared_error = 20890540.822\nsamples = 2\nvalue = 636723.185'),
#  Text(0.015202223202280539, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 641293.802'),
#  Text(0.015464330498871581, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 632152.568'),
#  Text(0.015136696378132777, 0.38571428571428573, 'X[0] <= 1935.5\nsquared_error = 1656978521.612\nsamples = 2\nvalue = 491780.188'),
#  Text(0.015005642729837256, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 532486.189'),
#  Text(0.015267750026428299, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 451074.186'),
#  Text(0.0185154232482517, 0.4142857142857143, 'X[4] <= 453.0\nsquared_error = 2428842265.323\nsamples = 49\nvalue = 563341.92'),
#  Text(0.01680763039390068, 0.38571428571428573, 'X[5] <= 6485.5\nsquared_error = 1849823793.235\nsamples = 29\nvalue = 583235.743'),
#  Text(0.015857491443758146, 0.35714285714285715, 'X[3] <= 648.0\nsquared_error = 69734958.216\nsamples = 3\nvalue = 508727.457'),
#  Text(0.015726437795462626, 0.32857142857142857, 'X[1] <= 926.0\nsquared_error = 15524823.945\nsamples = 2\nvalue = 503278.371'),
#  Text(0.015595384147167103, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 507218.527'),
#  Text(0.015857491443758146, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 499338.216'),
#  Text(0.01598854509205367, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 519625.629'),
#  Text(0.017757769344043214, 0.35714285714285715, 'X[5] <= 8917.0\nsquared_error = 1340752433.185\nsamples = 26\nvalue = 591832.853'),
#  Text(0.01684039380597456, 0.32857142857142857, 'X[3] <= 762.0\nsquared_error = 902001183.868\nsamples = 21\nvalue = 580975.093'),
#  Text(0.01611959874034919, 0.3, 'X[2] <= 408.0\nsquared_error = 497240908.69\nsamples = 10\nvalue = 566724.992'),
#  Text(0.015791964619610386, 0.2714285714285714, 'X[5] <= 7427.0\nsquared_error = 18414990.286\nsamples = 2\nvalue = 598336.646'),
#  Text(0.015660910971314865, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 594045.377'),
#  Text(0.01592301826790591, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 602627.915'),
#  Text(0.016447232861087995, 0.2714285714285714, 'X[4] <= 311.0\nsquared_error = 304667173.515\nsamples = 8\nvalue = 558822.078'),
#  Text(0.01618512556449695, 0.24285714285714285, 'X[10] <= 0.5\nsquared_error = 135591130.468\nsamples = 3\nvalue = 539148.54'),
#  Text(0.01605407191620143, 0.21428571428571427, 'X[5] <= 7497.0\nsquared_error = 41794053.248\nsamples = 2\nvalue = 531809.315'),
#  Text(0.01592301826790591, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 538274.148'),
#  Text(0.01618512556449695, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 525344.483'),
#  Text(0.016316179212792475, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 553826.989'),
#  Text(0.01670934015767904, 0.24285714285714285, 'X[0] <= 1979.5\nsquared_error = 34546611.659\nsamples = 5\nvalue = 570626.201'),
#  Text(0.01657828650938352, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 560466.982'),
#  Text(0.01684039380597456, 0.21428571428571427, 'X[1] <= 1045.0\nsquared_error = 10930223.935\nsamples = 4\nvalue = 573166.006'),
#  Text(0.01657828650938352, 0.18571428571428572, 'X[5] <= 7472.5\nsquared_error = 1405.52\nsamples = 2\nvalue = 569965.378'),
#  Text(0.016447232861087995, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 570002.868'),
#  Text(0.01670934015767904, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 569927.888'),
#  Text(0.017102501102565604, 0.18571428571428572, 'X[3] <= 446.0\nsquared_error = 1371005.592\nsamples = 2\nvalue = 576366.634'),
#  Text(0.016971447454270084, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 575195.734'),
#  Text(0.01723355475086113, 0.15714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 577537.533'),
#  Text(0.017561188871599933, 0.3, 'X[3] <= 862.0\nsquared_error = 917537534.835\nsamples = 11\nvalue = 593929.731'),
#  Text(0.017102501102565604, 0.2714285714285714, 'X[2] <= 792.0\nsquared_error = 523049151.04\nsamples = 3\nvalue = 622791.368'),
#  Text(0.016971447454270084, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 592885.713'),
#  Text(0.01723355475086113, 0.24285714285714285, 'X[4] <= 388.0\nsquared_error = 113812552.433\nsamples = 2\nvalue = 637744.196'),
#  Text(0.017102501102565604, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 648412.492'),
#  Text(0.01736460839915665, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 627075.899'),
#  Text(0.018019876640634258, 0.2714285714285714, 'X[0] <= 1994.5\nsquared_error = 635958091.606\nsamples = 8\nvalue = 583106.617'),
#  Text(0.017888822992338738, 0.24285714285714285, 'X[5] <= 6908.0\nsquared_error = 366629067.846\nsamples = 7\nvalue = 576396.734'),
#  Text(0.017626715695747693, 0.21428571428571427, 'X[0] <= 1981.0\nsquared_error = 148397223.244\nsamples = 3\nvalue = 590853.093'),
#  Text(0.017495662047452173, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 574992.415'),
#  Text(0.017757769344043214, 0.18571428571428572, 'X[12] <= 0.5\nsquared_error = 33924992.662\nsamples = 2\nvalue = 598783.432'),
#  Text(0.017626715695747693, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 604607.949'),
#  Text(0.017888822992338738, 0.15714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 592958.916'),
#  Text(0.018150930288929782, 0.21428571428571427, 'X[5] <= 7575.5\nsquared_error = 256008425.075\nsamples = 4\nvalue = 565554.465'),
#  Text(0.018019876640634258, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 548535.234'),
#  Text(0.018281983937225302, 0.18571428571428572, 'X[0] <= 1986.5\nsquared_error = 212609354.982\nsamples = 3\nvalue = 571227.542'),
#  Text(0.018150930288929782, 0.15714285714285714, 'X[2] <= 992.5\nsquared_error = 12208488.593\nsamples = 2\nvalue = 581338.684'),
#  Text(0.018019876640634258, 0.12857142857142856, 'squared_error = 0.0\nsamples = 1\nvalue = 584832.749'),
#  Text(0.018281983937225302, 0.12857142857142856, 'squared_error = 0.0\nsamples = 1\nvalue = 577844.619'),
#  Text(0.018413037585520823, 0.15714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 551005.26'),
#  Text(0.018150930288929782, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 630075.794'),
#  Text(0.018675144882111867, 0.32857142857142857, 'X[4] <= 300.0\nsquared_error = 608769184.664\nsamples = 5\nvalue = 637435.446'),
#  Text(0.018544091233816347, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 604123.561'),
#  Text(0.01880619853040739, 0.3, 'X[3] <= 1044.5\nsquared_error = 414185953.422\nsamples = 4\nvalue = 645763.418'),
#  Text(0.018675144882111867, 0.2714285714285714, 'X[6] <= 0.5\nsquared_error = 55513308.283\nsamples = 3\nvalue = 656907.19'),
#  Text(0.018544091233816347, 0.24285714285714285, 'X[3] <= 878.5\nsquared_error = 16898549.276\nsamples = 2\nvalue = 661610.785'),
#  Text(0.018413037585520823, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 665721.569'),
#  Text(0.018675144882111867, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 657500.0'),
#  Text(0.01880619853040739, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 647500.0'),
#  Text(0.018937252178702912, 0.2714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 612332.101'),
#  Text(0.02022321610260272, 0.38571428571428573, 'X[0] <= 1976.5\nsquared_error = 1862466669.947\nsamples = 20\nvalue = 534495.876'),
#  Text(0.019821864304697685, 0.35714285714285715, 'X[25] <= 0.5\nsquared_error = 251033937.824\nsamples = 2\nvalue = 456737.442'),
#  Text(0.01969081065640216, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 440893.391'),
#  Text(0.019952917952993206, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 472581.492'),
#  Text(0.020624567900507755, 0.35714285714285715, 'X[23] <= 0.5\nsquared_error = 1295048821.107\nsamples = 18\nvalue = 543135.702'),
#  Text(0.02021502524958425, 0.32857142857142857, 'X[3] <= 926.0\nsquared_error = 1454295795.967\nsamples = 12\nvalue = 553438.538'),
#  Text(0.019789100892623805, 0.3, 'X[2] <= 840.0\nsquared_error = 1211425905.251\nsamples = 10\nvalue = 544860.27'),
#  Text(0.019330413123589477, 0.2714285714285714, 'X[4] <= 532.5\nsquared_error = 148730343.576\nsamples = 5\nvalue = 537357.217'),
#  Text(0.019068305826998432, 0.24285714285714285, 'X[0] <= 1980.0\nsquared_error = 69841091.239\nsamples = 3\nvalue = 545689.168'),
#  Text(0.018937252178702912, 0.21428571428571427, 'X[1] <= 1008.0\nsquared_error = 1326359.812\nsamples = 2\nvalue = 539817.335'),
#  Text(0.01880619853040739, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 538665.658'),
#  Text(0.019068305826998432, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 540969.011'),
#  Text(0.019199359475293956, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 557432.834'),
#  Text(0.01959252042018052, 0.24285714285714285, 'X[0] <= 1980.0\nsquared_error = 6733944.636\nsamples = 2\nvalue = 524859.29'),
#  Text(0.019461466771885, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 527454.275'),
#  Text(0.01972357406847604, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 522264.306'),
#  Text(0.02024778866165813, 0.2714285714285714, 'X[0] <= 1987.5\nsquared_error = 2161529846.539\nsamples = 5\nvalue = 552363.324'),
#  Text(0.02011673501336261, 0.24285714285714285, 'X[2] <= 944.0\nsquared_error = 2646499891.184\nsamples = 4\nvalue = 549034.287'),
#  Text(0.019985681365067086, 0.21428571428571427, 'X[2] <= 882.0\nsquared_error = 3422360622.213\nsamples = 3\nvalue = 543879.05'),
#  Text(0.019854627716771565, 0.18571428571428572, 'squared_error = 5127189692.174\nsamples = 2\nvalue = 545334.069'),
#  Text(0.02011673501336261, 0.18571428571428572, 'squared_error = -0.0\nsamples = 1\nvalue = 540969.011'),
#  Text(0.02024778866165813, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 564500.0'),
#  Text(0.020378842309953654, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 565679.469'),
#  Text(0.020640949606544695, 0.3, 'X[5] <= 11323.0\nsquared_error = 461044679.291\nsamples = 2\nvalue = 596329.88'),
#  Text(0.020509895958249175, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 617801.83'),
#  Text(0.02077200325484022, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 574857.929'),
#  Text(0.021034110551431263, 0.32857142857142857, 'X[5] <= 7793.0\nsquared_error = 339664202.328\nsamples = 6\nvalue = 522530.028'),
#  Text(0.02090305690313574, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 551109.935'),
#  Text(0.021165164199726784, 0.3, 'X[3] <= 798.0\nsquared_error = 211562391.171\nsamples = 5\nvalue = 516814.047'),
#  Text(0.021034110551431263, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 541842.286'),
#  Text(0.021296217848022304, 0.2714285714285714, 'X[5] <= 10241.5\nsquared_error = 68699007.953\nsamples = 4\nvalue = 510556.987'),
#  Text(0.021034110551431263, 0.24285714285714285, 'X[4] <= 465.5\nsquared_error = 57108515.9\nsamples = 2\nvalue = 504488.069'),
#  Text(0.02090305690313574, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 512045.087'),
#  Text(0.021165164199726784, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 496931.051'),
#  Text(0.02155832514461335, 0.24285714285714285, 'X[1] <= 1080.0\nsquared_error = 6625962.793\nsamples = 2\nvalue = 516625.905'),
#  Text(0.02142727149631783, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 519200.0'),
#  Text(0.021689378792908873, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 514051.811'),
#  Text(0.025206326307714477, 0.5, 'X[15] <= 0.5\nsquared_error = 5533455070.825\nsamples = 62\nvalue = 602608.622'),
#  Text(0.022705044567199167, 0.4714285714285714, 'X[5] <= 8891.5\nsquared_error = 5390176129.609\nsamples = 13\nvalue = 679949.205'),
#  Text(0.02227912021023872, 0.44285714285714284, 'X[0] <= 1990.5\nsquared_error = 2554878877.628\nsamples = 10\nvalue = 650869.871'),
#  Text(0.022148066561943198, 0.4142857142857143, 'X[10] <= 0.5\nsquared_error = 1223312280.279\nsamples = 9\nvalue = 663579.875'),
#  Text(0.021689378792908873, 0.38571428571428573, 'X[1] <= 1207.0\nsquared_error = 439581821.117\nsamples = 6\nvalue = 645486.38'),
#  Text(0.02142727149631783, 0.35714285714285715, 'X[1] <= 1165.0\nsquared_error = 54100144.11\nsamples = 2\nvalue = 625421.911'),
#  Text(0.021296217848022304, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 618066.631'),
#  Text(0.02155832514461335, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 632777.191'),
#  Text(0.021951486089499914, 0.35714285714285715, 'X[0] <= 1982.5\nsquared_error = 330385478.028\nsamples = 4\nvalue = 655518.615'),
#  Text(0.021820432441204393, 0.32857142857142857, 'X[5] <= 6331.0\nsquared_error = 60942108.996\nsamples = 3\nvalue = 665259.917'),
#  Text(0.021689378792908873, 0.3, 'X[3] <= 142.0\nsquared_error = 15988218.485\nsamples = 2\nvalue = 670274.061'),
#  Text(0.02155832514461335, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 674272.588'),
#  Text(0.021820432441204393, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 666275.534'),
#  Text(0.021951486089499914, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 655231.627'),
#  Text(0.022082539737795438, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 626294.708'),
#  Text(0.022606754330977523, 0.38571428571428573, 'X[3] <= 262.5\nsquared_error = 826525766.658\nsamples = 3\nvalue = 699766.866'),
#  Text(0.022475700682682002, 0.35714285714285715, 'X[2] <= 150.0\nsquared_error = 247633353.537\nsamples = 2\nvalue = 717952.532'),
#  Text(0.022344647034386482, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 733688.902'),
#  Text(0.022606754330977523, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 702216.161'),
#  Text(0.022737807979273047, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 663395.535'),
#  Text(0.022410173858534242, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 536479.835'),
#  Text(0.02313096892415961, 0.44285714285714284, 'X[5] <= 14091.5\nsquared_error = 2626834417.675\nsamples = 3\nvalue = 776880.317'),
#  Text(0.02299991527586409, 0.4142857142857143, 'X[1] <= 1208.5\nsquared_error = 961165262.751\nsamples = 2\nvalue = 808392.676'),
#  Text(0.022868861627568567, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 777390.011'),
#  Text(0.02313096892415961, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 839395.341'),
#  Text(0.023262022572455136, 0.4142857142857143, 'squared_error = -0.0\nsamples = 1\nvalue = 713855.598'),
#  Text(0.02770760804822979, 0.4714285714285714, 'X[0] <= 1989.5\nsquared_error = 3563495343.081\nsamples = 49\nvalue = 582089.692'),
#  Text(0.025960908642041036, 0.44285714285714284, 'X[5] <= 10857.0\nsquared_error = 1855593067.134\nsamples = 33\nvalue = 557415.142'),
#  Text(0.02426949749372696, 0.4142857142857143, 'X[2] <= 204.0\nsquared_error = 1828246498.399\nsamples = 27\nvalue = 565345.023'),
#  Text(0.023393076220750656, 0.38571428571428573, 'X[0] <= 1977.5\nsquared_error = 1162511630.654\nsamples = 4\nvalue = 520146.53'),
#  Text(0.023262022572455136, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 480705.922'),
#  Text(0.023524129869046177, 0.35714285714285715, 'X[1] <= 1268.5\nsquared_error = 858654816.151\nsamples = 3\nvalue = 533293.399'),
#  Text(0.023393076220750656, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 492097.301'),
#  Text(0.0236551835173417, 0.32857142857142857, 'X[1] <= 1354.5\nsquared_error = 15143366.047\nsamples = 2\nvalue = 553891.448'),
#  Text(0.023524129869046177, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 557782.896'),
#  Text(0.02378623716563722, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 550000.0'),
#  Text(0.02514591876670326, 0.38571428571428573, 'X[5] <= 6956.5\nsquared_error = 1526949700.55\nsamples = 23\nvalue = 573205.631'),
#  Text(0.024179398110523786, 0.35714285714285715, 'X[4] <= 325.0\nsquared_error = 1204437348.565\nsamples = 6\nvalue = 543173.015'),
#  Text(0.024048344462228265, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 474790.808'),
#  Text(0.02431045175881931, 0.32857142857142857, 'X[5] <= 6788.0\nsquared_error = 323054515.911\nsamples = 5\nvalue = 556849.457'),
#  Text(0.024048344462228265, 0.3, 'X[3] <= 204.0\nsquared_error = 28943592.535\nsamples = 3\nvalue = 569894.339'),
#  Text(0.023917290813932745, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 576966.5'),
#  Text(0.024179398110523786, 0.2714285714285714, 'X[23] <= 0.5\nsquared_error = 5903797.055\nsamples = 2\nvalue = 566358.259'),
#  Text(0.024048344462228265, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 568788.032'),
#  Text(0.02431045175881931, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 563928.486'),
#  Text(0.024572559055410354, 0.3, 'X[0] <= 1987.0\nsquared_error = 126087277.907\nsamples = 2\nvalue = 537282.132'),
#  Text(0.02444150540711483, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 526053.273'),
#  Text(0.024703612703705875, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 548510.992'),
#  Text(0.026112439422882733, 0.35714285714285715, 'X[5] <= 8835.5\nsquared_error = 1210084840.27\nsamples = 17\nvalue = 583805.378'),
#  Text(0.025555461417626768, 0.32857142857142857, 'X[6] <= 0.5\nsquared_error = 716740724.003\nsamples = 11\nvalue = 596615.334'),
#  Text(0.025227827296887963, 0.3, 'X[1] <= 1416.0\nsquared_error = 467162000.448\nsamples = 9\nvalue = 588086.962'),
#  Text(0.02496572000029692, 0.2714285714285714, 'X[0] <= 1975.5\nsquared_error = 206011801.613\nsamples = 7\nvalue = 596702.49'),
#  Text(0.024834666352001395, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 570855.369'),
#  Text(0.02509677364859244, 0.24285714285714285, 'X[3] <= 596.0\nsquared_error = 110443890.124\nsamples = 6\nvalue = 601010.344'),
#  Text(0.024769139527853635, 0.21428571428571427, 'X[1] <= 1184.0\nsquared_error = 15545015.284\nsamples = 4\nvalue = 594151.197'),
#  Text(0.02450703223126259, 0.18571428571428572, 'X[0] <= 1985.5\nsquared_error = 177846.812\nsamples = 2\nvalue = 590220.161'),
#  Text(0.02437597858296707, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 590641.88'),
#  Text(0.024638085879558114, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 589798.442'),
#  Text(0.02503124682444468, 0.18571428571428572, 'X[0] <= 1986.0\nsquared_error = 6095.994\nsamples = 2\nvalue = 598082.233'),
#  Text(0.02490019317614916, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 598160.31'),
#  Text(0.0251623004727402, 0.15714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 598004.156'),
#  Text(0.025424407769331244, 0.21428571428571427, 'X[0] <= 1982.5\nsquared_error = 17954275.666\nsamples = 2\nvalue = 614728.637'),
#  Text(0.025293354121035724, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 610491.389'),
#  Text(0.025555461417626768, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 618965.886'),
#  Text(0.025489934593479004, 0.2714285714285714, 'X[5] <= 7463.5\nsquared_error = 212107344.503\nsamples = 2\nvalue = 557932.614'),
#  Text(0.025358880945183484, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 572496.519'),
#  Text(0.02562098824177453, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 543368.708'),
#  Text(0.025883095538365573, 0.3, 'X[1] <= 1464.5\nsquared_error = 39699998.232\nsamples = 2\nvalue = 634993.009'),
#  Text(0.02575204189007005, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 641293.802'),
#  Text(0.026014149186661093, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 628692.215'),
#  Text(0.026669417428138702, 0.32857142857142857, 'X[5] <= 10394.5\nsquared_error = 1262166749.164\nsamples = 6\nvalue = 560320.457'),
#  Text(0.026538363779843182, 0.3, 'X[3] <= 523.5\nsquared_error = 300418762.0\nsamples = 5\nvalue = 546095.003'),
#  Text(0.026276256483252138, 0.2714285714285714, 'X[5] <= 9445.5\nsquared_error = 130969185.44\nsamples = 2\nvalue = 528809.76'),
#  Text(0.026145202834956617, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 540253.937'),
#  Text(0.026407310131547658, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 517365.584'),
#  Text(0.026800471076434226, 0.2714285714285714, 'X[4] <= 495.0\nsquared_error = 81407819.011\nsamples = 3\nvalue = 557618.497'),
#  Text(0.026669417428138702, 0.24285714285714285, 'X[3] <= 615.5\nsquared_error = 202985.371\nsamples = 2\nvalue = 551243.841'),
#  Text(0.026538363779843182, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 551694.38'),
#  Text(0.026800471076434226, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 550793.302'),
#  Text(0.026931524724729747, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 570367.811'),
#  Text(0.026800471076434226, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 631447.73'),
#  Text(0.027652319790355116, 0.4142857142857143, 'X[1] <= 1522.0\nsquared_error = 422298044.038\nsamples = 6\nvalue = 521730.678'),
#  Text(0.02732468566961631, 0.38571428571428573, 'X[1] <= 1378.0\nsquared_error = 231040094.545\nsamples = 4\nvalue = 532457.828'),
#  Text(0.027062578373025267, 0.35714285714285715, 'X[1] <= 1306.0\nsquared_error = 2184300.873\nsamples = 2\nvalue = 517950.24'),
#  Text(0.026931524724729747, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 519428.178'),
#  Text(0.02719363202132079, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 516472.302'),
# ...
#  Text(0.0573687345413647, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 601425.475'),
#  Text(0.05763084183795575, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 615881.449'),
#  Text(0.05867927102431992, 0.21428571428571427, 'X[0] <= 1985.5\nsquared_error = 899925345.865\nsamples = 13\nvalue = 628691.251'),
#  Text(0.05815505643113784, 0.18571428571428572, 'X[2] <= 1051.5\nsquared_error = 844067734.171\nsamples = 6\nvalue = 612425.733'),
#  Text(0.05789294913454679, 0.15714285714285714, 'X[5] <= 11395.0\nsquared_error = 144193556.772\nsamples = 3\nvalue = 636566.4'),
#  Text(0.05776189548625127, 0.12857142857142856, 'X[1] <= 1315.5\nsquared_error = 39283685.244\nsamples = 2\nvalue = 644247.69'),
#  Text(0.05763084183795575, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 637980.021'),
#  Text(0.05789294913454679, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 650515.36'),
#  Text(0.05802400278284231, 0.12857142857142856, 'squared_error = 0.0\nsamples = 1\nvalue = 621203.82'),
#  Text(0.05841716372772888, 0.15714285714285714, 'X[14] <= 2.5\nsquared_error = 378398312.676\nsamples = 3\nvalue = 588285.066'),
#  Text(0.05828611007943336, 0.12857142857142856, 'X[0] <= 1982.5\nsquared_error = 46070075.288\nsamples = 2\nvalue = 601470.0'),
#  Text(0.05815505643113784, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 594682.506'),
#  Text(0.05841716372772888, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 608257.494'),
#  Text(0.0585482173760244, 0.12857142857142856, 'squared_error = 0.0\nsamples = 1\nvalue = 561915.2'),
#  Text(0.05920348561750201, 0.18571428571428572, 'X[4] <= 550.0\nsquared_error = 526655750.965\nsamples = 7\nvalue = 642633.122'),
#  Text(0.05907243196920649, 0.15714285714285714, 'X[5] <= 10862.5\nsquared_error = 326990199.13\nsamples = 6\nvalue = 636225.075'),
#  Text(0.05881032467261545, 0.12857142857142856, 'X[0] <= 2008.5\nsquared_error = 145292330.962\nsamples = 4\nvalue = 625501.185'),
#  Text(0.05867927102431992, 0.1, 'X[13] <= 0.5\nsquared_error = 36546230.867\nsamples = 3\nvalue = 631769.696'),
#  Text(0.0585482173760244, 0.07142857142857142, 'squared_error = 0.0\nsamples = 1\nvalue = 639676.464'),
#  Text(0.05881032467261545, 0.07142857142857142, 'X[0] <= 1992.5\nsquared_error = 7931611.148\nsamples = 2\nvalue = 627816.312'),
#  Text(0.05867927102431992, 0.04285714285714286, 'squared_error = 0.0\nsamples = 1\nvalue = 630632.623'),
#  Text(0.05894137832091097, 0.04285714285714286, 'squared_error = 0.0\nsamples = 1\nvalue = 625000.0'),
#  Text(0.05894137832091097, 0.1, 'squared_error = -0.0\nsamples = 1\nvalue = 606695.655'),
#  Text(0.05933453926579753, 0.12857142857142856, 'X[4] <= 477.5\nsquared_error = 375104.679\nsamples = 2\nvalue = 657672.854'),
#  Text(0.05920348561750201, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 657060.396'),
#  Text(0.059465592914093056, 0.1, 'squared_error = -0.0\nsamples = 1\nvalue = 658285.312'),
#  Text(0.05933453926579753, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 681081.408'),
#  Text(0.0582205832552856, 0.24285714285714285, 'squared_error = -0.001\nsamples = 1\nvalue = 553768.433'),
#  Text(0.05792571254662067, 0.32857142857142857, 'X[14] <= 2.5\nsquared_error = 388801835.635\nsamples = 2\nvalue = 550123.001'),
#  Text(0.05779465889832515, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 569841.06'),
#  Text(0.05805676619491619, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 530404.943'),
#  Text(0.0565619355190454, 0.38571428571428573, 'squared_error = 1162650990.126\nsamples = 2\nvalue = 691151.959'),
#  Text(0.05669298916734092, 0.4142857142857143, 'squared_error = -0.002\nsamples = 1\nvalue = 465029.611'),
#  Text(0.05721720376052301, 0.4714285714285714, 'X[0] <= 2000.0\nsquared_error = 1378185878.991\nsamples = 4\nvalue = 714187.061'),
#  Text(0.057086150112227486, 0.44285714285714284, 'X[5] <= 8576.5\nsquared_error = 306752278.671\nsamples = 3\nvalue = 694624.157'),
#  Text(0.056955096463931966, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 672034.139'),
#  Text(0.05721720376052301, 0.4142857142857143, 'X[3] <= 1481.5\nsquared_error = 77396740.23\nsamples = 2\nvalue = 705919.166'),
#  Text(0.057086150112227486, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 697121.624'),
#  Text(0.05734825740881853, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 714716.707'),
#  Text(0.05734825740881853, 0.44285714285714284, 'squared_error = 0.0\nsamples = 1\nvalue = 772875.774'),
#  Text(0.06212966785835046, 0.5, 'X[14] <= 2.5\nsquared_error = 2867349889.25\nsamples = 75\nvalue = 650164.334'),
#  Text(0.059936566962655084, 0.4714285714285714, 'X[5] <= 6428.0\nsquared_error = 2575688747.699\nsamples = 45\nvalue = 632601.547'),
#  Text(0.05859736249413522, 0.44285714285714284, 'X[15] <= 0.5\nsquared_error = 1710899693.752\nsamples = 19\nvalue = 602264.497'),
#  Text(0.0584663088458397, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 708438.165'),
#  Text(0.058728416142430746, 0.4142857142857143, 'X[1] <= 1071.5\nsquared_error = 1144887614.459\nsamples = 18\nvalue = 596365.96'),
#  Text(0.0582205832552856, 0.38571428571428573, 'X[0] <= 1992.0\nsquared_error = 600701634.881\nsamples = 4\nvalue = 561812.432'),
#  Text(0.05808952960699008, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 528073.11'),
#  Text(0.05835163690358112, 0.35714285714285715, 'X[4] <= 383.5\nsquared_error = 295005815.125\nsamples = 3\nvalue = 573058.872'),
#  Text(0.0582205832552856, 0.32857142857142857, 'squared_error = 439681855.132\nsamples = 2\nvalue = 574029.588'),
#  Text(0.05848269055187664, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 571117.44'),
#  Text(0.05923624902957589, 0.38571428571428573, 'X[4] <= 320.0\nsquared_error = 861776800.7\nsamples = 14\nvalue = 606238.396'),
#  Text(0.05910519538128037, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 654486.735'),
#  Text(0.059367302677871416, 0.35714285714285715, 'X[1] <= 1339.5\nsquared_error = 735223355.788\nsamples = 13\nvalue = 602526.986'),
#  Text(0.058744797848467686, 0.32857142857142857, 'X[0] <= 1994.0\nsquared_error = 270841709.983\nsamples = 5\nvalue = 586606.733'),
#  Text(0.05848269055187664, 0.3, 'X[12] <= 0.5\nsquared_error = 47858816.362\nsamples = 2\nvalue = 605450.25'),
#  Text(0.05835163690358112, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 612368.257'),
#  Text(0.05861374420017216, 0.2714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 598532.243'),
#  Text(0.05900690514505873, 0.3, 'X[3] <= 622.0\nsquared_error = 24965728.451\nsamples = 3\nvalue = 574044.389'),
#  Text(0.05887585149676321, 0.2714285714285714, 'X[0] <= 2003.5\nsquared_error = 2014812.243\nsamples = 2\nvalue = 577481.14'),
#  Text(0.058744797848467686, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 578900.581'),
#  Text(0.05900690514505873, 0.24285714285714285, 'squared_error = -0.0\nsamples = 1\nvalue = 576061.699'),
#  Text(0.05913795879335425, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 567170.886'),
#  Text(0.059989807507275145, 0.32857142857142857, 'X[5] <= 5596.5\nsquared_error = 768047219.112\nsamples = 8\nvalue = 612477.144'),
#  Text(0.05966217338653634, 0.3, 'X[5] <= 4703.5\nsquared_error = 784564044.06\nsamples = 4\nvalue = 595835.944'),
#  Text(0.059400066089945296, 0.2714285714285714, 'X[3] <= 313.0\nsquared_error = 210769802.475\nsamples = 2\nvalue = 620840.551'),
#  Text(0.05926901244164977, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 606322.638'),
#  Text(0.059531119738240816, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 635358.464'),
#  Text(0.05992428068312738, 0.2714285714285714, 'X[5] <= 5101.0\nsquared_error = 107897597.784\nsamples = 2\nvalue = 570831.338'),
#  Text(0.05979322703483186, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 560443.961'),
#  Text(0.060055334331422905, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 581218.715'),
#  Text(0.060317441628013946, 0.3, 'X[3] <= 288.0\nsquared_error = 197671377.123\nsamples = 4\nvalue = 629118.343'),
#  Text(0.060186387979718425, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 610868.596'),
#  Text(0.060448495276309466, 0.2714285714285714, 'X[2] <= 732.0\nsquared_error = 115538169.1\nsamples = 3\nvalue = 635201.592'),
#  Text(0.060317441628013946, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 620121.751'),
#  Text(0.06057954892460499, 0.24285714285714285, 'X[3] <= 720.0\nsquared_error = 2756062.698\nsamples = 2\nvalue = 642741.512'),
#  Text(0.060448495276309466, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 644401.651'),
#  Text(0.060710602572900514, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 641081.372'),
#  Text(0.06127577143117495, 0.44285714285714284, 'X[5] <= 6807.0\nsquared_error = 2043614755.391\nsamples = 26\nvalue = 654770.93'),
#  Text(0.060317441628013946, 0.4142857142857143, 'X[1] <= 1256.0\nsquared_error = 1112713571.925\nsamples = 4\nvalue = 702784.237'),
#  Text(0.060186387979718425, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 648754.956'),
#  Text(0.060448495276309466, 0.38571428571428573, 'X[3] <= 708.0\nsquared_error = 186212220.205\nsamples = 3\nvalue = 720793.997'),
#  Text(0.060317441628013946, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 738821.824'),
#  Text(0.06057954892460499, 0.35714285714285715, 'X[0] <= 1993.0\nsquared_error = 35566422.115\nsamples = 2\nvalue = 711780.084'),
#  Text(0.060448495276309466, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 705816.325'),
#  Text(0.060710602572900514, 0.32857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 717743.843'),
#  Text(0.06223410123433595, 0.4142857142857143, 'X[0] <= 2007.5\nsquared_error = 1717520608.836\nsamples = 22\nvalue = 646041.238'),
#  Text(0.06210304758604043, 0.38571428571428573, 'X[2] <= 1180.0\nsquared_error = 1397446222.63\nsamples = 21\nvalue = 641767.316'),
#  Text(0.061595214698895284, 0.35714285714285715, 'X[3] <= 700.0\nsquared_error = 1055871995.213\nsamples = 19\nvalue = 635315.713'),
#  Text(0.060972709869491555, 0.32857142857142857, 'X[0] <= 1992.5\nsquared_error = 1187997489.301\nsamples = 4\nvalue = 607372.491'),
#  Text(0.060841656221196035, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 548796.758'),
#  Text(0.061103763517787076, 0.3, 'X[2] <= 860.0\nsquared_error = 59055983.693\nsamples = 3\nvalue = 626897.735'),
#  Text(0.060972709869491555, 0.2714285714285714, 'X[5] <= 7822.5\nsquared_error = 18003669.929\nsamples = 2\nvalue = 622047.295'),
#  Text(0.060841656221196035, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 626290.368'),
#  Text(0.061103763517787076, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 617804.222'),
#  Text(0.061234817166082596, 0.2714285714285714, 'squared_error = -0.0\nsamples = 1\nvalue = 636598.615'),
#  Text(0.06221771952829901, 0.32857142857142857, 'X[4] <= 528.5\nsquared_error = 756893642.574\nsamples = 15\nvalue = 642767.239'),
#  Text(0.061759031759264685, 0.3, 'X[5] <= 7661.0\nsquared_error = 544654877.901\nsamples = 12\nvalue = 651605.733'),
#  Text(0.061496924462673644, 0.2714285714285714, 'X[1] <= 1449.0\nsquared_error = 290820908.292\nsamples = 8\nvalue = 639026.835'),
#  Text(0.06136587081437812, 0.24285714285714285, 'X[4] <= 450.0\nsquared_error = 90672856.409\nsamples = 6\nvalue = 633018.105'),
#  Text(0.061234817166082596, 0.21428571428571427, 'X[0] <= 1996.0\nsquared_error = 61748370.52\nsamples = 5\nvalue = 635818.672'),
#  Text(0.061103763517787076, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 636663.288'),
#  Text(0.06136587081437812, 0.18571428571428572, 'X[1] <= 1169.0\nsquared_error = 76962533.064\nsamples = 4\nvalue = 635607.518'),
#  Text(0.061234817166082596, 0.15714285714285714, 'squared_error = 102603596.014\nsamples = 3\nvalue = 635664.778'),
#  Text(0.061496924462673644, 0.15714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 635435.739'),
#  Text(0.061496924462673644, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 619015.27'),
#  Text(0.061627978110969164, 0.24285714285714285, 'squared_error = 458007059.699\nsamples = 2\nvalue = 657053.024'),
#  Text(0.06202113905585573, 0.2714285714285714, 'X[4] <= 425.0\nsquared_error = 102950709.663\nsamples = 4\nvalue = 676763.53'),
#  Text(0.061890085407560205, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 692526.055'),
#  Text(0.06215219270415125, 0.24285714285714285, 'X[1] <= 1180.0\nsquared_error = 26842194.847\nsamples = 3\nvalue = 671509.355'),
#  Text(0.06202113905585573, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 678717.065'),
#  Text(0.062283246352446774, 0.21428571428571427, 'X[4] <= 465.0\nsquared_error = 1299984.704\nsamples = 2\nvalue = 667905.5'),
#  Text(0.06215219270415125, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 669045.669'),
#  Text(0.062414300000742294, 0.18571428571428572, 'squared_error = 0.0\nsamples = 1\nvalue = 666765.332'),
#  Text(0.06267640729733334, 0.3, 'X[1] <= 1103.5\nsquared_error = 43469140.03\nsamples = 3\nvalue = 607413.263'),
#  Text(0.06254535364903782, 0.2714285714285714, 'X[4] <= 565.0\nsquared_error = 328353.771\nsamples = 2\nvalue = 612063.544'),
#  Text(0.062414300000742294, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 611490.523'),
#  Text(0.06267640729733334, 0.24285714285714285, 'squared_error = 0.0\nsamples = 1\nvalue = 612636.566'),
#  Text(0.06280746094562886, 0.2714285714285714, 'squared_error = 0.0\nsamples = 1\nvalue = 598112.7'),
#  Text(0.06261088047318558, 0.35714285714285715, 'X[3] <= 594.0\nsquared_error = 490490006.768\nsamples = 2\nvalue = 703057.537'),
#  Text(0.062479826824890054, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 680910.528'),
#  Text(0.0627419341214811, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 725204.546'),
#  Text(0.062365154882631474, 0.38571428571428573, 'squared_error = 0.0\nsamples = 1\nvalue = 735793.609'),
#  Text(0.06432276875404583, 0.4714285714285714, 'X[4] <= 382.0\nsquared_error = 2148148488.561\nsamples = 30\nvalue = 676508.515'),
#  Text(0.0637575998957714, 0.44285714285714284, 'X[1] <= 1290.0\nsquared_error = 670525152.06\nsamples = 2\nvalue = 797866.352'),
#  Text(0.06362654624747588, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 771971.852'),
#  Text(0.06388865354406692, 0.4142857142857143, 'squared_error = 0.0\nsamples = 1\nvalue = 823760.853'),
#  Text(0.06488793761232027, 0.44285714285714284, 'X[1] <= 1276.5\nsquared_error = 1126571232.546\nsamples = 28\nvalue = 667840.098'),
#  Text(0.06415076084065796, 0.4142857142857143, 'X[3] <= 1024.0\nsquared_error = 1089403782.567\nsamples = 10\nvalue = 646378.608'),
#  Text(0.06365930965954976, 0.38571428571428573, 'X[1] <= 1182.0\nsquared_error = 940196510.722\nsamples = 7\nvalue = 657545.822'),
#  Text(0.06333167553881094, 0.35714285714285715, 'X[5] <= 9920.5\nsquared_error = 1001016528.44\nsamples = 5\nvalue = 666369.446'),
#  Text(0.0630695682422199, 0.32857142857142857, 'X[5] <= 7294.5\nsquared_error = 721297773.631\nsamples = 3\nvalue = 676484.006'),
#  Text(0.06293851459392438, 0.3, 'squared_error = 1080695021.044\nsamples = 2\nvalue = 677129.926'),
#  Text(0.06320062189051542, 0.3, 'squared_error = -0.0\nsamples = 1\nvalue = 675192.165'),
#  Text(0.063593782835402, 0.32857142857142857, 'X[2] <= 1024.0\nsquared_error = 1036953432.577\nsamples = 2\nvalue = 651197.605'),
#  Text(0.06346272918710646, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 618995.844'),
#  Text(0.06372483648369752, 0.3, 'squared_error = 0.0\nsamples = 1\nvalue = 683399.367'),
#  Text(0.06398694378028856, 0.35714285714285715, 'X[4] <= 412.0\nsquared_error = 106903545.835\nsamples = 2\nvalue = 635486.763'),
#  Text(0.06385589013199304, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 645826.18'),
#  Text(0.06411799742858408, 0.32857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 625147.346'),
#  ...]

# %%
R2 = 1 - (np.sum((y_test-y_pred)**2)/np.sum((y_test-np.mean(y_test))**2))
print(R2)
# Out:
# 0.7467113630378405

# %%
# Plot the predictions
plt.figure()

# Build a scatterplot

x = np.linspace(0,8000000,)
plt.plot(x,x, color = 'r')
plt.ylim((0,8000000))
plt.xlim((0,8000000))
plt.scatter(y_test, y_pred)

# Label it nicely
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.title('Predicted price vs actual price: Random Forest Regression')
plt.show()

# %% [markdown]
# R squared 0f 0.746 vs 0.741 for linear regression - not a great improvement. However, it does look like the model mistreats everyone equally.

# %% [markdown]
# ### Random Forest

# %%
# Fitting Linear Regression to the dataset
lin = LinearRegression()
lin.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
  
poly = PolynomialFeatures(degree = 2, interaction_only=False)
X_poly = poly.fit_transform(X_train)
poly.fit(X_poly, y_train )

lin2 = LinearRegression()
lin2.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
X_poly.shape
# Out:
# (8030, 435)

# %%
X_poly
# Out:
# array([[1.000e+00, 1.996e+03, 1.515e+03, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [1.000e+00, 1.992e+03, 1.560e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.012e+03, 2.387e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        ...,
#        [1.000e+00, 2.007e+03, 1.276e+03, ..., 0.000e+00, 0.000e+00,
#         1.000e+00],
#        [1.000e+00, 2.016e+03, 1.948e+03, ..., 1.000e+00, 0.000e+00,
#         0.000e+00],
#        [1.000e+00, 2.003e+03, 3.932e+03, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]])

# %%
polynom = lin2.predict(poly.fit_transform(X_test)) # predict on the test set

# %%
polynom
# Out:
# array([1308681.74994873, 1872506.47558118,  576126.14063144, ...,
#         979363.03396457, 1273172.97202934,  798867.890126  ])

# %%
R2 = 1 - (np.sum((y_test-polynom)**2)/np.sum((y_test-np.mean(y_test))**2))
print(R2)
# Out:
# 0.8688554615735771

# %%
# Plot the predictions
plt.figure()

# Build a scatterplot

x = np.linspace(0,8000000,)
plt.plot(x,x, color = 'r')
plt.ylim((0,8000000))
plt.xlim((0,8000000))
plt.scatter(y_test, polynom)

# Label it nicely
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.title('Predicted price vs actual price: Polynomial Regression')
plt.show()

# %% [markdown]
# Well it looks like polynomial regression did a great job, with R^2 at 0.869 versus 0.746 for Descision tree and 0.741 for linear regression. To check for overfitting, I would like to calculate R2 on train set to see the difference between test and train set.

# %%
poly_train = lin2.predict(poly.fit_transform(X_train)) # predict on the test set

# %%
poly_train = lin2.predict(poly.fit_transform(X_train)) # predict on the test set
R2 = 1 - (np.sum((y_train-poly_train)**2)/np.sum((y_train-np.mean(y_train))**2))
print(R2)
# Out:
# 0.8974110147436896

# %% [markdown]
# Well R2 on train set is 0.897 and R2 on test set is 0.869, so it is smaller yet still very goood. Let's do predictions vs actuals plot

# %%
# Plot the predictions
plt.figure()

# Build a scatterplot

x = np.linspace(0,8000000,)
plt.plot(x,x, color = 'r')
plt.ylim((0,8000000))
plt.xlim((0,8000000))
plt.scatter(y_test, polynom)

# Label it nicely
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.title('Predicted price vs actual price: Polynomial Regression')
plt.show()

# %%
Well this looks much much better, however the 3 million dollars and up the relationship doesn't seem to hold up as well, but those observations are not very numerous. I would like to investigate them and see what could drive that.

# %%
# this is for polynomial regression, not used
from sklearn.preprocessing import PowerTransformer
poly = PolynomialFeatures(degree = 2, interaction_only=False)
X_poly_train = poly.fit_transform(X_train)
X_poly_test = poly.fit_transform(X_test)

# %% [markdown]
# #### Multiple linear regression model with log transformed response

# %%
# log 10 transform y_test and y_train

from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(np.log10)
y_train_log  = transformer.transform(y_train)
y_test_log = transformer.transform(y_test)

# %%
lin2 = LinearRegression()
reg = lin2.fit(X_train, y_train_log)

# %%
log_test = reg.predict(X_test) # predict on the test set
R2 = 1 - (np.sum((y_test_log-log_test)**2)/np.sum((y_test_log-np.mean(y_test_log))**2))
print("Test set R^2: ",R2)

log_train = reg.predict(X_train) # predict on the test set
R2 = 1 - (np.sum((y_train_log-log_train)**2)/np.sum((y_train_log-np.mean(y_train_log))**2))
print("Train set R^2: ",R2)
# Out:
# Test set R^2:  0.9014472707324583
# Train set R^2:  0.8946883463178541

# %%
print(np.min(polynom),
np.max(polynom),
np.min(y_test_log),
np.max(y_test_log))
# Out:
# 5.3344064203213115 6.607207784283053 5.271210356886041 6.87345827577024

# %%
# Plot the predictions
plt.figure()

# Build a scatterplot
x = np.linspace(0,8,)
plt.plot(x,x, color = 'r')

plt.scatter(y_test_log, polynom)
plt.xlim(5,7.1)
plt.ylim(5,7.1)


# Label it nicely
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.title('Predicted price vs actual price: Linear Regression with log response')
plt.show()

# %%
Test set R^2:  0.9014472707324583 <br>Train set R^2:  0.8946883463178541

# %% [markdown]
# ### refit the model with stats models to get the output

# %%
X_train_const = sm.add_constant(features)
X_train, X_test, y_train, y_test = train_test_split(X_train_const, Y, test_size = 0.25, train_size = 0.75)
transformer = FunctionTransformer(np.log10)
y_train_log  = transformer.transform(y_train)

# %%
X_train.shape
# Out:
# (8030, 29)

# %%
model = sm.OLS(y_train_log,X_train)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Time Adjust Sales Price   R-squared:                       0.895
# Model:                                 OLS   Adj. R-squared:                  0.895
# Method:                      Least Squares   F-statistic:                     2536.
# Date:                     Tue, 07 Mar 2023   Prob (F-statistic):               0.00
# Time:                             12:11:08   Log-Likelihood:                 10899.
# No. Observations:                     8030   AIC:                        -2.174e+04
# Df Residuals:                         8002   BIC:                        -2.155e+04
# Df Model:                               27
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  3.4812      0.131     26.490      0.000       3.224       3.739
# Eff Yr Built           0.0011   6.81e-05     16.450      0.000       0.001       0.001
# Above Grd SF        5.972e-05   1.62e-06     36.754      0.000    5.65e-05    6.29e-05
# Basemt Tot SF       7.171e-06    1.8e-06      3.980      0.000    3.64e-06    1.07e-05
# Basemt Fin SF       3.236e-05   1.62e-06     19.918      0.000    2.92e-05    3.55e-05
# Garage SF           4.345e-05   4.62e-06      9.413      0.000    3.44e-05    5.25e-05
# Est Land SF         1.953e-06   9.46e-08     20.635      0.000    1.77e-06    2.14e-06
# Unincorporated         0.0143      0.005      2.627      0.009       0.004       0.025
# Design_1 Sty Townh    -0.3019      0.050     -6.091      0.000      -0.399      -0.205
# Design_Bi Level       -0.2923      0.044     -6.584      0.000      -0.379      -0.205
# Design_Modular        -0.5456      0.051    -10.689      0.000      -0.646      -0.446
# Design_Multi Sty      -0.3168      0.044     -7.164      0.000      -0.403      -0.230
# Design_Paired         -0.3536      0.045     -7.922      0.000      -0.441      -0.266
# Design_Ranch          -0.3077      0.044     -6.957      0.000      -0.394      -0.221
# Design_Split level    -0.3025      0.044     -6.832      0.000      -0.389      -0.216
# Quality_cat            0.0275      0.001     51.172      0.000       0.026       0.029
# Garage Attached       -0.0285      0.002    -12.246      0.000      -0.033      -0.024
# Market Area_101        0.4989      0.011     45.698      0.000       0.478       0.520
# Market Area_102        0.3555      0.011     31.478      0.000       0.333       0.378
# Market Area_103        0.4397      0.011     38.951      0.000       0.418       0.462
# Market Area_104        0.3132      0.012     27.214      0.000       0.291       0.336
# Market Area_105        0.2964      0.011     26.679      0.000       0.275       0.318
# Market Area_106        0.4198      0.011     37.874      0.000       0.398       0.442
# Market Area_107        0.4448      0.011     39.185      0.000       0.423       0.467
# Market Area_401        0.1809      0.012     15.328      0.000       0.158       0.204
# Market Area_402        0.1425      0.011     12.418      0.000       0.120       0.165
# Market Area_403        0.2185      0.011     19.410      0.000       0.196       0.241
# Market Area_404        0.0547      0.012      4.527      0.000       0.031       0.078
# Market Area_405        0.1164      0.011     10.198      0.000       0.094       0.139
# ==============================================================================
# Omnibus:                     1010.651   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9472.131
# Skew:                           0.255   Prob(JB):                         0.00
# Kurtosis:                       8.296   Cond. No.                     2.46e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.94e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# All variables are significant. Durbin Watson is great.  R^2 is 0.895

# %% [markdown]
# ### Performing 6-fold cross validation on the linear regression with log response model

# %%
y_log  = transformer.transform(Y)

# %%
# Import the necessary modules
from sklearn.model_selection import cross_val_score, KFold

# Create a KFold object
kf = KFold(n_splits=6, shuffle=True, random_state=5)

reg = LinearRegression()

# Compute 6-fold cross-validation scores
cv_scores = cross_val_score(reg, features, y_log, cv=kf)

# Print scores
print(cv_scores)

# Print the mean
print("Mean R^2: ",np.mean(cv_scores))

# Print the standard deviation
print("Standard deviation R^2: ",np.std(cv_scores))

# Print the 95% confidence interval
print(np.percentile(cv_scores, [2.5, 97.5]))
# Out:
# [0.89990313 0.90039066 0.85533091 0.90119968 0.8962117  0.8897804 ]
# Mean R^2:  0.8904694140902012
# Standard deviation R^2:  0.016179862032652013
# [0.8596371  0.90109855]
